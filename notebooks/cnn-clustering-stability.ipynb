# %% [markdown]
# # CNN Clustering Significance Stability over Multiple Trainings
#
# ### Before Running on Perceptron
#
# Go to `src/train_nn.py` to line 46, and change the path `./models/` to `/scratch/<your username>/models`
#
# Do not forget to undo this change!
#
# DO NOT COMMIT THIS CHANGE TO GITHUB!!!

# %%
# %load_ext autoreload
# %autoreload 1

# %%
import sys
sys.path.append('..')

import random
import subprocess
from multiprocessing import Pool

import numpy as np
import matplotlib.pylab as plt
import pandas as pd
from tqdm.notebook import tqdm, trange
from IPython import display

from src.visualization import draw_mlp_clustering_report, run_double_spectral_cluster, run_spectral_cluster
from src.utils import get_weights_paths, build_clustering_results, cohen_d_stats
from src.experiment_tagging import get_model_path, MODEL_TAG_LOOKUP
# from src.spectral_cluster_model import SHUFFLE_METHODS
SHUFFLE_METHODS = ['layer', 'layer_nonzero']
# Out:
# /home/arda/.miniconda3/envs/mod/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.neighbors.kde module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/arda/.miniconda3/envs/mod/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/arda/.miniconda3/envs/mod/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/arda/.miniconda3/envs/mod/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/arda/.miniconda3/envs/mod/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/arda/.miniconda3/envs/mod/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/arda/.miniconda3/envs/mod/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
N_TRAINED_MODELS = 5

# we are doing 30 experiments (=6 models x 5 times)
# we do 40 shuffles
N_SHUFFLES = 40

N_GPUS = 1

TAGS_COMMANDS = {
    'CNN:MNIST': 'python -m src.train_nn with cnn_config dataset_name=mnist',
    'CNN:FASHION': 'python -m src.train_nn with cnn_config dataset_name=fashion',
    'CNN:CIFAR10': 'python -m src.train_nn with cnn_config dataset_name=cifar10',
    'CNN:MNIST+DROPOUT': 'python -m src.train_nn with cnn_config dataset_name=mnist with_dropout=True',
    'CNN:FASHION+DROPOUT': 'python -m src.train_nn with cnn_config dataset_name=fashion with_dropout=True',
    'CNN:CIFAR10+DROPOUT': 'python -m src.train_nn with cnn_config dataset_name=cifar10 with_dropout=True'
}
DATASETS_TAGS = [command.split()[5][13:] for command in TAGS_COMMANDS.values()]

# %%
if False:
    def train_model_multiply(command, n_models_per_command, gpu_id=None):    
        for _ in range(n_models_per_command):
            actual_command = f'cd .. && {command}' #' > log.log 2>&1'
            print(actual_command)
            subprocess.run(actual_command, shell=True,
                           env={'CUDA_VISIBLE_DEVICES': str(gpu_id)})


    def train_models(commands, n_models_per_command, gpu_id=None):
        for command in commands:
            train_model_multiply(command, n_models_per_command, gpu_id)

    commands = list(TAGS_COMMANDS.values())
    random.shuffle(commands)

    assert len(commands) % N_GPUS == 0
    n_commands_per_gpu = len(commands) // N_GPUS

    with Pool(N_GPUS) as p:

        p.starmap(train_models,
                 [(commands[gpu_id*n_commands_per_gpu : (gpu_id+1)*n_commands_per_gpu], N_TRAINED_MODELS, gpu_id)
                 for gpu_id in range(N_GPUS)])
# Out:
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist
# cd .. && python -m src.train_nn with cnn_config dataset_name=mnist
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=fashion with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10 with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10 with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10 with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10 with_dropout=True
# cd .. && python -m src.train_nn with cnn_config dataset_name=cifar10 with_dropout=True

# %%
results = {}

for shuffle_method in SHUFFLE_METHODS:
    results[shuffle_method] = {}
    
    for (model_tag, _), dataset_tag in zip(TAGS_COMMANDS.items(), tqdm(DATASETS_TAGS)):
        model_paths = get_model_path(model_tag, filter_='all')


        results[shuffle_method][model_tag] = [run_spectral_cluster(path / f'{dataset_tag}-cnn-pruned-weights.pckl',
                                               n_samples=N_SHUFFLES,
                                               shuffle_method=shuffle_method)
            for path in tqdm(model_paths[-N_TRAINED_MODELS:])]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=6.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=6.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
def build_all_models_per_shuffle_method_df(single_shuffle_method_results):
    model_dfs = []

    for model_tag, model_results in single_shuffle_method_results.items():
        _, metrics  = zip(*model_results)
        model_dfs.append(pd.DataFrame(metrics).assign(model=model_tag))

    df = pd.concat(model_dfs, ignore_index=True)

    df['is_sig'] = np.isclose(df['percentile'], 1 / (N_SHUFFLES + 1))
    
    return df

layer_df = build_all_models_per_shuffle_method_df(results['layer'])
layer_nonzero_df = build_all_models_per_shuffle_method_df(results['layer_nonzero'])

# %%
layer_df.head()
# Out:
#        ncut  ave_in_out  n_samples      mean     stdev   z_score  percentile  \
# 0  0.486664    3.609615         40  0.330076  0.038982  4.016928    1.000000
# 1  0.315247    5.844222         40  0.331046  0.035524 -0.444726    0.195122
# 2  0.501487    3.488143         40  0.336751  0.037949  4.340922    1.000000
# 3  0.319131    5.767016         40  0.338664  0.031092 -0.628243    0.146341
# 4  0.491144    3.572124         40  0.339505  0.023668  6.406966    1.000000
#
#    train_acc  train_loss  test_acc  test_loss      model  is_sig
# 0   0.999950    0.000733    0.9901   0.039492  CNN:MNIST   False
# 1   0.999967    0.000744    0.9899   0.039181  CNN:MNIST   False
# 2   0.999867    0.000940    0.9877   0.044666  CNN:MNIST   False
# 3   1.000000    0.000629    0.9888   0.045396  CNN:MNIST   False
# 4   0.999950    0.000703    0.9890   0.042868  CNN:MNIST   False

# %%
layer_nonzero_df.head()
# Out:
#        ncut  ave_in_out  n_samples      mean     stdev   z_score  percentile  \
# 0  0.486664    3.609615         40  0.494100  0.012158 -0.611626    0.243902
# 1  0.315247    5.844222         40  0.334218  0.079026 -0.240056    0.048780
# 2  0.501487    3.488143         40  0.497428  0.070506  0.057558    0.560976
# 3  0.319131    5.767016         40  0.318392  0.021595  0.034227    0.951220
# 4  0.491144    3.572124         40  0.493979  0.015910 -0.178166    0.414634
#
#    train_acc  train_loss  test_acc  test_loss      model  is_sig
# 0   0.999950    0.000733    0.9901   0.039492  CNN:MNIST   False
# 1   0.999967    0.000744    0.9899   0.039181  CNN:MNIST   False
# 2   0.999867    0.000940    0.9877   0.044666  CNN:MNIST   False
# 3   1.000000    0.000629    0.9888   0.045396  CNN:MNIST   False
# 4   0.999950    0.000703    0.9890   0.042868  CNN:MNIST   False

# %%
MODEL_DATA_COLUMNS = ['model',
                      'train_acc', 'train_loss', 'test_acc', 'test_loss',
                      'ncut', 'ave_in_out',
                      'n_samples']

assert layer_df[MODEL_DATA_COLUMNS].equals(layer_nonzero_df[MODEL_DATA_COLUMNS])

SHUFFLING_DATA_COLUMNS = ['mean', 'percentile', 'stdev', 'z_score', 'is_sig']

two_shuffling_method_df = pd.merge(layer_df[SHUFFLING_DATA_COLUMNS],
                                     layer_nonzero_df[SHUFFLING_DATA_COLUMNS],
                                     left_index=True, right_index=True,
                                     suffixes=('_layer', '_layer_nonzero'))

assert layer_df[MODEL_DATA_COLUMNS].equals(layer_nonzero_df[MODEL_DATA_COLUMNS])

df = pd.merge(layer_df[MODEL_DATA_COLUMNS], two_shuffling_method_df,
              left_index=True, right_index=True,)

df['cohen_d'] = df.apply(lambda r: cohen_d_stats(r['mean_layer'], r['stdev_layer'], r['n_samples'],
                                 r['mean_layer_nonzero'], r['stdev_layer_nonzero'], r['n_samples']),
                                axis=1)

df
# Out:
#                   model  train_acc  train_loss  test_acc  test_loss      ncut  \
# 0             CNN:MNIST   0.999950    0.000733    0.9901   0.039492  0.486664
# 1             CNN:MNIST   0.999967    0.000744    0.9899   0.039181  0.315247
# 2             CNN:MNIST   0.999867    0.000940    0.9877   0.044666  0.501487
# 3             CNN:MNIST   1.000000    0.000629    0.9888   0.045396  0.319131
# 4             CNN:MNIST   0.999950    0.000703    0.9890   0.042868  0.491144
# 5           CNN:FASHION   0.990850    0.032584    0.9193   0.335111  0.490673
# 6           CNN:CIFAR10   0.805480    0.570816    0.6183   1.227513  0.458650
# 7           CNN:CIFAR10   0.793860    0.602530    0.6180   1.175385  0.523723
# 8           CNN:CIFAR10   0.815480    0.544781    0.6217   1.219707  0.470916
# 9           CNN:CIFAR10   0.821660    0.528239    0.6225   1.209161  0.504985
# 10          CNN:CIFAR10   0.791820    0.612807    0.6219   1.195162  1.220759
# 11    CNN:MNIST+DROPOUT   0.969167    0.100232    0.9891   0.037257  0.305152
# 12    CNN:MNIST+DROPOUT   0.968750    0.102297    0.9884   0.038700  0.304693
# 13    CNN:MNIST+DROPOUT   0.966250    0.113027    0.9879   0.039542  0.233853
# 14    CNN:MNIST+DROPOUT   0.966700    0.108829    0.9875   0.037195  0.311790
# 15    CNN:MNIST+DROPOUT   0.968900    0.100467    0.9888   0.035488  0.307341
# 16  CNN:FASHION+DROPOUT   0.865283    0.367835    0.8980   0.274157  0.291258
# 17  CNN:FASHION+DROPOUT   0.862267    0.383069    0.8999   0.280477  0.287037
# 18  CNN:FASHION+DROPOUT   0.859767    0.380043    0.9020   0.273947  0.298471
# 19  CNN:FASHION+DROPOUT   0.858817    0.388357    0.9009   0.281381  0.294486
# 20  CNN:FASHION+DROPOUT   0.853517    0.377123    0.9067   0.264276  0.291722
# 21  CNN:CIFAR10+DROPOUT   0.506420    1.362655    0.5837   1.202204  0.314913
# 22  CNN:CIFAR10+DROPOUT   0.515000    1.352097    0.5884   1.203564  0.222221
# 23  CNN:CIFAR10+DROPOUT   0.494720    1.391593    0.5829   1.214101  0.337307
# 24  CNN:CIFAR10+DROPOUT   0.516980    1.341353    0.5825   1.216144  0.452690
# 25  CNN:CIFAR10+DROPOUT   0.503800    1.361673    0.5824   1.199175  0.231752
#
#     ave_in_out  n_samples  mean_layer  percentile_layer  stdev_layer  \
# 0     3.609615         40    0.330076          1.000000     0.038982
# 1     5.844222         40    0.331046          0.195122     0.035524
# 2     3.488143         40    0.336751          1.000000     0.037949
# 3     5.767016         40    0.338664          0.146341     0.031092
# 4     3.572124         40    0.339505          1.000000     0.023668
# 5     3.576031         40    0.301990          1.000000     0.017349
# 6     3.860626         40    0.333917          0.975610     0.054087
# 7     3.318811         40    0.440204          0.707317     0.108956
# 8     3.747046         40    0.437130          0.585366     0.154304
# 9     3.460512         40    0.306165          1.000000     0.023737
# 10    1.138326         40    0.467365          1.000000     0.045234
# 11    6.054115         40    0.307389          0.170732     0.027990
# 12    6.063983         40    0.315498          0.170732     0.028134
# 13    8.052369         40    0.309676          0.024390     0.047036
# 14    5.914571         40    0.317273          0.146341     0.032682
# 15    6.007432         40    0.314750          0.121951     0.024777
# 16    6.366768         40    0.304276          0.121951     0.020644
# 17    6.467734         40    0.300463          0.121951     0.021725
# 18    6.200822         40    0.308754          0.097561     0.017784
# 19    6.291483         40    0.302604          0.146341     0.026194
# 20    6.355849         40    0.298647          0.170732     0.024120
# 21    5.850958         40    0.306771          0.219512     0.033966
# 22    8.500034         40    0.230307          0.048780     0.005847
# 23    5.429319         40    0.271561          0.731707     0.057203
# 24    3.918033         40    0.322958          1.000000     0.027401
# 25    8.129924         40    0.234494          0.195122     0.002763
#
#     z_score_layer  is_sig_layer  mean_layer_nonzero  percentile_layer_nonzero  \
# 0        4.016928         False            0.494100                  0.243902
# 1       -0.444726         False            0.334218                  0.048780
# 2        4.340922         False            0.497428                  0.560976
# 3       -0.628243         False            0.318392                  0.951220
# 4        6.406966         False            0.493979                  0.414634
# 5       10.875814         False            0.490627                  0.585366
# 6        2.306170         False            0.472424                  0.439024
# 7        0.766536         False            0.519404                  0.268293
# 8        0.218953         False            0.410612                  0.975610
# 9        8.376005         False            0.486030                  0.634146
# 10      16.655540         False            1.253368                  0.463415
# 11      -0.079936         False            0.306760                  0.243902
# 12      -0.384043         False            0.313520                  0.195122
# 13      -1.612015          True            0.264203                  0.341463
# 14      -0.167748         False            0.311810                  0.487805
# 15      -0.299033         False            0.308326                  0.048780
# 16      -0.630605         False            0.298324                  0.048780
# 17      -0.617975         False            0.362831                  0.073171
# 18      -0.578243         False            0.282748                  0.365854
# 19      -0.309890         False            0.523591                  0.024390
# 20      -0.287101         False            0.306795                  0.024390
# 21       0.239699         False            0.314073                  0.878049
# 22      -1.383006         False            0.223540                  0.097561
# 23       1.149349         False            0.322490                  1.000000
# 24       4.734544         False            0.481386                  0.268293
# 25      -0.992629         False            0.286371                  0.048780
#
#     stdev_layer_nonzero  z_score_layer_nonzero  is_sig_layer_nonzero   cohen_d
# 0              0.012158              -0.611626                 False  0.332024
# 1              0.079026              -0.240056                 False  0.159385
# 2              0.070506               0.057558                 False  0.166434
# 3              0.021595               0.034227                 False  0.305234
# 4              0.015910              -0.178166                 False  0.328154
# 5              0.002221               0.020690                 False  0.483302
# 6              0.047159              -0.292090                 False  0.187902
# 7              0.031938               0.135244                 False  0.259662
# 8              0.017777               3.392140                 False  0.293978
# 9              0.030281               0.625974                 False  0.228896
# 10             0.242275              -0.134597                 False  0.122994
# 11             0.004581              -0.351006                 False  0.517129
# 12             0.037246              -0.236992                 False  0.222364
# 13             0.037990              -0.798875                 False  0.203152
# 14             0.000458              -0.043357                 False  0.816018
# 15             0.000474              -2.079361                 False  0.837014
# 16             0.012446              -0.567713                 False  0.360934
# 17             0.125428              -0.604281                 False  0.119928
# 18             0.034620               0.454148                 False  0.234439
# 19             0.167151              -1.370639                  True  0.102343
# 20             0.036914              -0.408349                  True  0.213607
# 21             0.000713               1.178210                 False  0.745642
# 22             0.001159              -1.137872                 False  0.704925
# 23             0.024306               0.609600                 False  0.201457
# 24             0.039890              -0.719367                 False  0.213218
# 25             0.037716              -1.448155                 False  0.179173

# %%
# df = pd.read_csv('../results/cnn-clustering-stability-two-shuffling-methods-all-samples.csv' index_col=0)

# %%
df_grpby_model = df.groupby('model')

TWO_SHUFFLE_STATS_COLUMNS = [f'{stat}_{shuffle_method}'
                             for stat in ['mean', 'stdev', 'z_score', 'percentile', 'is_sig']
                             for shuffle_method in SHUFFLE_METHODS]

statistics_df = pd.concat([(df_grpby_model[['ncut'] + TWO_SHUFFLE_STATS_COLUMNS]
                             .agg(['mean', 'std'])),
                            df_grpby_model.size().rename('n_models'),
                            (df_grpby_model[['train_acc', 'test_acc']]
                             .agg('mean'))],
                           axis=1)

# %%
statistics_df
# Out:
#                      (ncut, mean)  (ncut, std)  (mean_layer, mean)  \
# model
# CNN:CIFAR10              0.635806     0.328032            0.396956
# CNN:CIFAR10+DROPOUT      0.311777     0.093464            0.273218
# CNN:FASHION              0.490673          NaN            0.301990
# CNN:FASHION+DROPOUT      0.292595     0.004229            0.302949
# CNN:MNIST                0.422735     0.096509            0.335208
# CNN:MNIST+DROPOUT        0.292566     0.032941            0.312917
#
#                      (mean_layer, std)  (mean_layer_nonzero, mean)  \
# model
# CNN:CIFAR10                   0.071866                    0.628368
# CNN:CIFAR10+DROPOUT           0.041664                    0.325572
# CNN:FASHION                        NaN                    0.490627
# CNN:FASHION+DROPOUT           0.003882                    0.354858
# CNN:MNIST                     0.004372                    0.427623
# CNN:MNIST+DROPOUT             0.004185                    0.300924
#
#                      (mean_layer_nonzero, std)  (stdev_layer, mean)  \
# model
# CNN:CIFAR10                           0.351602             0.077264
# CNN:CIFAR10+DROPOUT                   0.095350             0.025436
# CNN:FASHION                                NaN             0.017349
# CNN:FASHION+DROPOUT                   0.099046             0.022093
# CNN:MNIST                             0.092670             0.033443
# CNN:MNIST+DROPOUT                     0.020703             0.032124
#
#                      (stdev_layer, std)  (stdev_layer_nonzero, mean)  \
# model
# CNN:CIFAR10                    0.053310                     0.073886
# CNN:CIFAR10+DROPOUT            0.022269                     0.020757
# CNN:FASHION                         NaN                     0.002221
# CNN:FASHION+DROPOUT            0.003230                     0.075312
# CNN:MNIST                      0.006253                     0.039839
# CNN:MNIST+DROPOUT              0.008799                     0.016150
#
#                      (stdev_layer_nonzero, std)  ...  (percentile_layer, std)  \
# model                                            ...
# CNN:CIFAR10                            0.094708  ...                 0.194358
# CNN:CIFAR10+DROPOUT                    0.019053  ...                 0.406301
# CNN:FASHION                                 NaN  ...                      NaN
# CNN:FASHION+DROPOUT                    0.067135  ...                 0.027809
# CNN:MNIST                              0.032202  ...                 0.454536
# CNN:MNIST+DROPOUT                      0.019671  ...                 0.060731
#
#                      (percentile_layer_nonzero, mean)  \
# model
# CNN:CIFAR10                                  0.556098
# CNN:CIFAR10+DROPOUT                          0.458537
# CNN:FASHION                                  0.585366
# CNN:FASHION+DROPOUT                          0.107317
# CNN:MNIST                                    0.443902
# CNN:MNIST+DROPOUT                            0.263415
#
#                      (percentile_layer_nonzero, std)  (is_sig_layer, mean)  \
# model
# CNN:CIFAR10                                 0.267960                   0.0
# CNN:CIFAR10+DROPOUT                         0.448210                   0.0
# CNN:FASHION                                      NaN                   0.0
# CNN:FASHION+DROPOUT                         0.145934                   0.0
# CNN:MNIST                                   0.342073                   0.0
# CNN:MNIST+DROPOUT                           0.163978                   0.2
#
#                      (is_sig_layer, std)  (is_sig_layer_nonzero, mean)  \
# model
# CNN:CIFAR10                     0.000000                           0.0
# CNN:CIFAR10+DROPOUT             0.000000                           0.0
# CNN:FASHION                          NaN                           0.0
# CNN:FASHION+DROPOUT             0.000000                           0.4
# CNN:MNIST                       0.000000                           0.0
# CNN:MNIST+DROPOUT               0.447214                           0.0
#
#                      (is_sig_layer_nonzero, std)  n_models  train_acc  \
# model
# CNN:CIFAR10                             0.000000         5   0.805660
# CNN:CIFAR10+DROPOUT                     0.000000         5   0.507384
# CNN:FASHION                                  NaN         1   0.990850
# CNN:FASHION+DROPOUT                     0.547723         5   0.859930
# CNN:MNIST                               0.000000         5   0.999947
# CNN:MNIST+DROPOUT                       0.000000         5   0.967953
#
#                      test_acc
# model
# CNN:CIFAR10           0.62048
# CNN:CIFAR10+DROPOUT   0.58398
# CNN:FASHION           0.91930
# CNN:FASHION+DROPOUT   0.90150
# CNN:MNIST             0.98910
# CNN:MNIST+DROPOUT     0.98834
#
# [6 rows x 25 columns]

# %%
# TODO: ask for a code review
# std = np.sqrt(np.mean(x**2) - np.mean(x)**2)

def calc_overall_stdev(row, suffix=''):
    return np.sqrt(                 # 5. apply root square to get the SD from the variance
        (np.mean(                   # 3. divide by the number of trained model
            (row[f'stdev{suffix}']**2)       # 1. cancel the overall square root
             + row[f'mean{suffix}']**2))     # 2. add the mean and get the sum or squares
        - np.mean(row[f'mean{suffix}'])**2)  # 4. substrct the square of the overall mean

# %%
SHUFFLE_METHOD_SUFFIX = ['_layer', '_layer_nonzero']
for suffix in SHUFFLE_METHOD_SUFFIX:
    statistics_df[f'overall_std{suffix}'] = df_grpby_model.apply(calc_overall_stdev, suffix)

for suffix in SHUFFLE_METHOD_SUFFIX:
    statistics_df[f'is_stable{suffix}'] = (statistics_df[(f'is_sig{suffix}', 'mean')] == 1)

statistics_df = statistics_df.loc[TAGS_COMMANDS.keys(), :]

# %%
statistics_df
# Out:
#                      (ncut, mean)  (ncut, std)  (mean_layer, mean)  \
# model
# CNN:MNIST                0.422735     0.096509            0.335208
# CNN:FASHION              0.490673          NaN            0.301990
# CNN:CIFAR10              0.635806     0.328032            0.396956
# CNN:MNIST+DROPOUT        0.292566     0.032941            0.312917
# CNN:FASHION+DROPOUT      0.292595     0.004229            0.302949
# CNN:CIFAR10+DROPOUT      0.311777     0.093464            0.273218
#
#                      (mean_layer, std)  (mean_layer_nonzero, mean)  \
# model
# CNN:MNIST                     0.004372                    0.427623
# CNN:FASHION                        NaN                    0.490627
# CNN:CIFAR10                   0.071866                    0.628368
# CNN:MNIST+DROPOUT             0.004185                    0.300924
# CNN:FASHION+DROPOUT           0.003882                    0.354858
# CNN:CIFAR10+DROPOUT           0.041664                    0.325572
#
#                      (mean_layer_nonzero, std)  (stdev_layer, mean)  \
# model
# CNN:MNIST                             0.092670             0.033443
# CNN:FASHION                                NaN             0.017349
# CNN:CIFAR10                           0.351602             0.077264
# CNN:MNIST+DROPOUT                     0.020703             0.032124
# CNN:FASHION+DROPOUT                   0.099046             0.022093
# CNN:CIFAR10+DROPOUT                   0.095350             0.025436
#
#                      (stdev_layer, std)  (stdev_layer_nonzero, mean)  \
# model
# CNN:MNIST                      0.006253                     0.039839
# CNN:FASHION                         NaN                     0.002221
# CNN:CIFAR10                    0.053310                     0.073886
# CNN:MNIST+DROPOUT              0.008799                     0.016150
# CNN:FASHION+DROPOUT            0.003230                     0.075312
# CNN:CIFAR10+DROPOUT            0.022269                     0.020757
#
#                      (stdev_layer_nonzero, std)  ...  (is_sig_layer, std)  \
# model                                            ...
# CNN:MNIST                              0.032202  ...             0.000000
# CNN:FASHION                                 NaN  ...                  NaN
# CNN:CIFAR10                            0.094708  ...             0.000000
# CNN:MNIST+DROPOUT                      0.019671  ...             0.447214
# CNN:FASHION+DROPOUT                    0.067135  ...             0.000000
# CNN:CIFAR10+DROPOUT                    0.019053  ...             0.000000
#
#                      (is_sig_layer_nonzero, mean)  \
# model
# CNN:MNIST                                     0.0
# CNN:FASHION                                   0.0
# CNN:CIFAR10                                   0.0
# CNN:MNIST+DROPOUT                             0.0
# CNN:FASHION+DROPOUT                           0.4
# CNN:CIFAR10+DROPOUT                           0.0
#
#                      (is_sig_layer_nonzero, std)  n_models  train_acc  \
# model
# CNN:MNIST                               0.000000         5   0.999947
# CNN:FASHION                                  NaN         1   0.990850
# CNN:CIFAR10                             0.000000         5   0.805660
# CNN:MNIST+DROPOUT                       0.000000         5   0.967953
# CNN:FASHION+DROPOUT                     0.547723         5   0.859930
# CNN:CIFAR10+DROPOUT                     0.000000         5   0.507384
#
#                      test_acc  overall_std_layer  overall_std_layer_nonzero  \
# model
# CNN:MNIST             0.98910           0.034132                   0.096368
# CNN:FASHION           0.91930           0.017349                   0.002221
# CNN:CIFAR10           0.62048           0.111243                   0.333967
# CNN:MNIST+DROPOUT     0.98834           0.033285                   0.030221
# CNN:FASHION+DROPOUT   0.90150           0.022550                   0.130865
# CNN:CIFAR10+DROPOUT   0.58398           0.049320                   0.089413
#
#                      is_stable_layer  is_stable_layer_nonzero
# model
# CNN:MNIST                      False                    False
# CNN:FASHION                    False                    False
# CNN:CIFAR10                    False                    False
# CNN:MNIST+DROPOUT              False                    False
# CNN:FASHION+DROPOUT            False                    False
# CNN:CIFAR10+DROPOUT            False                    False
#
# [6 rows x 29 columns]

# %%
df.to_csv('../results/cnn-clustering-stability-two-shuffling-methods-all-samples.csv')
statistics_df.to_csv('../results/cnn-clustering-stability-two-shuffling-methods-statistics.csv')

# %% [markdown]
# ### Model Stability Statistics

# %%
statistics_df
# Out:
#                      (ncut, mean)  (ncut, std)  (mean_layer, mean)  \
# model
# CNN:MNIST                0.422735     0.096509            0.335208
# CNN:FASHION              0.490673          NaN            0.301990
# CNN:CIFAR10              0.635806     0.328032            0.396956
# CNN:MNIST+DROPOUT        0.292566     0.032941            0.312917
# CNN:FASHION+DROPOUT      0.292595     0.004229            0.302949
# CNN:CIFAR10+DROPOUT      0.311777     0.093464            0.273218
#
#                      (mean_layer, std)  (mean_layer_nonzero, mean)  \
# model
# CNN:MNIST                     0.004372                    0.427623
# CNN:FASHION                        NaN                    0.490627
# CNN:CIFAR10                   0.071866                    0.628368
# CNN:MNIST+DROPOUT             0.004185                    0.300924
# CNN:FASHION+DROPOUT           0.003882                    0.354858
# CNN:CIFAR10+DROPOUT           0.041664                    0.325572
#
#                      (mean_layer_nonzero, std)  (stdev_layer, mean)  \
# model
# CNN:MNIST                             0.092670             0.033443
# CNN:FASHION                                NaN             0.017349
# CNN:CIFAR10                           0.351602             0.077264
# CNN:MNIST+DROPOUT                     0.020703             0.032124
# CNN:FASHION+DROPOUT                   0.099046             0.022093
# CNN:CIFAR10+DROPOUT                   0.095350             0.025436
#
#                      (stdev_layer, std)  (stdev_layer_nonzero, mean)  \
# model
# CNN:MNIST                      0.006253                     0.039839
# CNN:FASHION                         NaN                     0.002221
# CNN:CIFAR10                    0.053310                     0.073886
# CNN:MNIST+DROPOUT              0.008799                     0.016150
# CNN:FASHION+DROPOUT            0.003230                     0.075312
# CNN:CIFAR10+DROPOUT            0.022269                     0.020757
#
#                      (stdev_layer_nonzero, std)  ...  (is_sig_layer, std)  \
# model                                            ...
# CNN:MNIST                              0.032202  ...             0.000000
# CNN:FASHION                                 NaN  ...                  NaN
# CNN:CIFAR10                            0.094708  ...             0.000000
# CNN:MNIST+DROPOUT                      0.019671  ...             0.447214
# CNN:FASHION+DROPOUT                    0.067135  ...             0.000000
# CNN:CIFAR10+DROPOUT                    0.019053  ...             0.000000
#
#                      (is_sig_layer_nonzero, mean)  \
# model
# CNN:MNIST                                     0.0
# CNN:FASHION                                   0.0
# CNN:CIFAR10                                   0.0
# CNN:MNIST+DROPOUT                             0.0
# CNN:FASHION+DROPOUT                           0.4
# CNN:CIFAR10+DROPOUT                           0.0
#
#                      (is_sig_layer_nonzero, std)  n_models  train_acc  \
# model
# CNN:MNIST                               0.000000         5   0.999947
# CNN:FASHION                                  NaN         1   0.990850
# CNN:CIFAR10                             0.000000         5   0.805660
# CNN:MNIST+DROPOUT                       0.000000         5   0.967953
# CNN:FASHION+DROPOUT                     0.547723         5   0.859930
# CNN:CIFAR10+DROPOUT                     0.000000         5   0.507384
#
#                      test_acc  overall_std_layer  overall_std_layer_nonzero  \
# model
# CNN:MNIST             0.98910           0.034132                   0.096368
# CNN:FASHION           0.91930           0.017349                   0.002221
# CNN:CIFAR10           0.62048           0.111243                   0.333967
# CNN:MNIST+DROPOUT     0.98834           0.033285                   0.030221
# CNN:FASHION+DROPOUT   0.90150           0.022550                   0.130865
# CNN:CIFAR10+DROPOUT   0.58398           0.049320                   0.089413
#
#                      is_stable_layer  is_stable_layer_nonzero
# model
# CNN:MNIST                      False                    False
# CNN:FASHION                    False                    False
# CNN:CIFAR10                    False                    False
# CNN:MNIST+DROPOUT              False                    False
# CNN:FASHION+DROPOUT            False                    False
# CNN:CIFAR10+DROPOUT            False                    False
#
# [6 rows x 29 columns]

# %% [markdown]
# ### Appendix - All Samples

# %%
df
# Out:
#                   model  train_acc  train_loss  test_acc  test_loss      ncut  \
# 0             CNN:MNIST   0.999950    0.000733    0.9901   0.039492  0.486664
# 1             CNN:MNIST   0.999967    0.000744    0.9899   0.039181  0.315247
# 2             CNN:MNIST   0.999867    0.000940    0.9877   0.044666  0.501487
# 3             CNN:MNIST   1.000000    0.000629    0.9888   0.045396  0.319131
# 4             CNN:MNIST   0.999950    0.000703    0.9890   0.042868  0.491144
# 5           CNN:FASHION   0.990850    0.032584    0.9193   0.335111  0.490673
# 6           CNN:CIFAR10   0.805480    0.570816    0.6183   1.227513  0.458650
# 7           CNN:CIFAR10   0.793860    0.602530    0.6180   1.175385  0.523723
# 8           CNN:CIFAR10   0.815480    0.544781    0.6217   1.219707  0.470916
# 9           CNN:CIFAR10   0.821660    0.528239    0.6225   1.209161  0.504985
# 10          CNN:CIFAR10   0.791820    0.612807    0.6219   1.195162  1.220759
# 11    CNN:MNIST+DROPOUT   0.969167    0.100232    0.9891   0.037257  0.305152
# 12    CNN:MNIST+DROPOUT   0.968750    0.102297    0.9884   0.038700  0.304693
# 13    CNN:MNIST+DROPOUT   0.966250    0.113027    0.9879   0.039542  0.233853
# 14    CNN:MNIST+DROPOUT   0.966700    0.108829    0.9875   0.037195  0.311790
# 15    CNN:MNIST+DROPOUT   0.968900    0.100467    0.9888   0.035488  0.307341
# 16  CNN:FASHION+DROPOUT   0.865283    0.367835    0.8980   0.274157  0.291258
# 17  CNN:FASHION+DROPOUT   0.862267    0.383069    0.8999   0.280477  0.287037
# 18  CNN:FASHION+DROPOUT   0.859767    0.380043    0.9020   0.273947  0.298471
# 19  CNN:FASHION+DROPOUT   0.858817    0.388357    0.9009   0.281381  0.294486
# 20  CNN:FASHION+DROPOUT   0.853517    0.377123    0.9067   0.264276  0.291722
# 21  CNN:CIFAR10+DROPOUT   0.506420    1.362655    0.5837   1.202204  0.314913
# 22  CNN:CIFAR10+DROPOUT   0.515000    1.352097    0.5884   1.203564  0.222221
# 23  CNN:CIFAR10+DROPOUT   0.494720    1.391593    0.5829   1.214101  0.337307
# 24  CNN:CIFAR10+DROPOUT   0.516980    1.341353    0.5825   1.216144  0.452690
# 25  CNN:CIFAR10+DROPOUT   0.503800    1.361673    0.5824   1.199175  0.231752
#
#     ave_in_out  n_samples  mean_layer  percentile_layer  stdev_layer  \
# 0     3.609615         40    0.330076          1.000000     0.038982
# 1     5.844222         40    0.331046          0.195122     0.035524
# 2     3.488143         40    0.336751          1.000000     0.037949
# 3     5.767016         40    0.338664          0.146341     0.031092
# 4     3.572124         40    0.339505          1.000000     0.023668
# 5     3.576031         40    0.301990          1.000000     0.017349
# 6     3.860626         40    0.333917          0.975610     0.054087
# 7     3.318811         40    0.440204          0.707317     0.108956
# 8     3.747046         40    0.437130          0.585366     0.154304
# 9     3.460512         40    0.306165          1.000000     0.023737
# 10    1.138326         40    0.467365          1.000000     0.045234
# 11    6.054115         40    0.307389          0.170732     0.027990
# 12    6.063983         40    0.315498          0.170732     0.028134
# 13    8.052369         40    0.309676          0.024390     0.047036
# 14    5.914571         40    0.317273          0.146341     0.032682
# 15    6.007432         40    0.314750          0.121951     0.024777
# 16    6.366768         40    0.304276          0.121951     0.020644
# 17    6.467734         40    0.300463          0.121951     0.021725
# 18    6.200822         40    0.308754          0.097561     0.017784
# 19    6.291483         40    0.302604          0.146341     0.026194
# 20    6.355849         40    0.298647          0.170732     0.024120
# 21    5.850958         40    0.306771          0.219512     0.033966
# 22    8.500034         40    0.230307          0.048780     0.005847
# 23    5.429319         40    0.271561          0.731707     0.057203
# 24    3.918033         40    0.322958          1.000000     0.027401
# 25    8.129924         40    0.234494          0.195122     0.002763
#
#     z_score_layer  is_sig_layer  mean_layer_nonzero  percentile_layer_nonzero  \
# 0        4.016928         False            0.494100                  0.243902
# 1       -0.444726         False            0.334218                  0.048780
# 2        4.340922         False            0.497428                  0.560976
# 3       -0.628243         False            0.318392                  0.951220
# 4        6.406966         False            0.493979                  0.414634
# 5       10.875814         False            0.490627                  0.585366
# 6        2.306170         False            0.472424                  0.439024
# 7        0.766536         False            0.519404                  0.268293
# 8        0.218953         False            0.410612                  0.975610
# 9        8.376005         False            0.486030                  0.634146
# 10      16.655540         False            1.253368                  0.463415
# 11      -0.079936         False            0.306760                  0.243902
# 12      -0.384043         False            0.313520                  0.195122
# 13      -1.612015          True            0.264203                  0.341463
# 14      -0.167748         False            0.311810                  0.487805
# 15      -0.299033         False            0.308326                  0.048780
# 16      -0.630605         False            0.298324                  0.048780
# 17      -0.617975         False            0.362831                  0.073171
# 18      -0.578243         False            0.282748                  0.365854
# 19      -0.309890         False            0.523591                  0.024390
# 20      -0.287101         False            0.306795                  0.024390
# 21       0.239699         False            0.314073                  0.878049
# 22      -1.383006         False            0.223540                  0.097561
# 23       1.149349         False            0.322490                  1.000000
# 24       4.734544         False            0.481386                  0.268293
# 25      -0.992629         False            0.286371                  0.048780
#
#     stdev_layer_nonzero  z_score_layer_nonzero  is_sig_layer_nonzero   cohen_d
# 0              0.012158              -0.611626                 False  0.332024
# 1              0.079026              -0.240056                 False  0.159385
# 2              0.070506               0.057558                 False  0.166434
# 3              0.021595               0.034227                 False  0.305234
# 4              0.015910              -0.178166                 False  0.328154
# 5              0.002221               0.020690                 False  0.483302
# 6              0.047159              -0.292090                 False  0.187902
# 7              0.031938               0.135244                 False  0.259662
# 8              0.017777               3.392140                 False  0.293978
# 9              0.030281               0.625974                 False  0.228896
# 10             0.242275              -0.134597                 False  0.122994
# 11             0.004581              -0.351006                 False  0.517129
# 12             0.037246              -0.236992                 False  0.222364
# 13             0.037990              -0.798875                 False  0.203152
# 14             0.000458              -0.043357                 False  0.816018
# 15             0.000474              -2.079361                 False  0.837014
# 16             0.012446              -0.567713                 False  0.360934
# 17             0.125428              -0.604281                 False  0.119928
# 18             0.034620               0.454148                 False  0.234439
# 19             0.167151              -1.370639                  True  0.102343
# 20             0.036914              -0.408349                  True  0.213607
# 21             0.000713               1.178210                 False  0.745642
# 22             0.001159              -1.137872                 False  0.704925
# 23             0.024306               0.609600                 False  0.201457
# 24             0.039890              -0.719367                 False  0.213218
# 25             0.037716              -1.448155                 False  0.179173

# %% [markdown]
# ### Unpruned results without shuffling
# #### TODO: Refactor
# - [ ] Combine with the unpruned table

# %%
unpruned_results = {}

for (model_tag, _), dataset_tag in zip(TAGS_COMMANDS.items(), tqdm(DATASETS_TAGS)):
    model_paths = get_model_path(model_tag, filter_='all')
    unpruned_results[model_tag] = [run_spectral_cluster(path / f'{dataset_tag}-mlp-unpruned-weights.pckl',
                                               with_shuffle=False)
            for path in tqdm(model_paths[-N_TRAINED_MODELS:])]
       
unpruned_model_dfs = []

for model_tag, model_results in unpruned_results.items():
    _, metrics  = zip(*model_results)
    unpruned_model_dfs.append(pd.DataFrame(metrics).assign(model=model_tag))

unpruned_df = pd.concat(unpruned_model_dfs, ignore_index=True)

unpruned_df_grpby_model = unpruned_df.groupby('model')


unpruned_statistics_df = pd.concat([(unpruned_df_grpby_model[['ncut']]
                             .agg(['mean', 'std'])),
                            unpruned_df_grpby_model.size().rename('n_models'),
                            (unpruned_df_grpby_model[['train_acc', 'test_acc']]
                             .agg('mean'))],
                           axis=1)

unpruned_statistics_df = unpruned_statistics_df.loc[TAGS_COMMANDS.keys(), :]

unpruned_statistics_df

# %%
unpruned_df.to_csv('../results/cnn-clustering-stability-all-samples-unpruned.csv')
unpruned_statistics_df.to_csv('../results/cnn-clustering-stability-statistics-unpruned.csv')
